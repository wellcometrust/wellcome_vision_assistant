# %%
try:
    import Image
except ImportError:
    from PIL import Image
import pytesseract

import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np

# %matplotlib inline

# %%
img=Image.open('../../data/postits/IMG_2837.JPG')
img = img.rotate(-90)

ocr_text = pytesseract.image_to_string(img)
print(f"OCR text: {ocr_text}")

plt.imshow(np.asarray(img))
# Out:
# OCR text:

# %%
img=Image.open('../../data/postits/IMG_2833.JPG')
img = img.rotate(-90)

ocr_text = pytesseract.image_to_string(img)
print(f"OCR text: {ocr_text}")

plt.imshow(np.asarray(img))
# Out:
# OCR text:
