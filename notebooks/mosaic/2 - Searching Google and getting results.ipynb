# %%
import requests

# %%
google_url = 'https://www.google.co.uk/search'
params = {
    'q': 'how can you treat someone who doesnt accept they are ill?'
}

response = requests.get(google_url, params=params)
print(response.text)
# Out:
# <!doctype html><html itemscope="" itemtype="http://schema.org/SearchResultsPage" lang="en-GB"><head><meta content="text/html; charset=UTF-8" http-equiv="Content-Type"><meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"><noscript><meta content="0;url=/search?q=how+can+you+treat+someone+who+doesnt+accept+they+are+ill%3F&amp;ie=UTF-8&amp;gbv=1&amp;sei=FfmtW6T8IdWtgAaU95uwBA" http-equiv="refresh"><style>table,div,span,p{display:none}</style><div style="display:block">Please click <a href="/search?q=how+can+you+treat+someone+who+doesnt+accept+they+are+ill%3F&amp;ie=UTF-8&amp;gbv=1&amp;sei=FfmtW6T8IdWtgAaU95uwBA">here</a> if you are not redirected within a few seconds.</div></noscript><title>how can you treat someone who doesnt accept they are ill? - Google Search</title><style>#gbar,#guser{font-size:13px;padding-top:1px !important;}#gbar{height:22px}#guser{padding-bottom:7px !important;text-align:right}.gbh,.gbd{border-top:1px solid #c9d7f1;font-s
# ...

# %%
from bs4 import BeautifulSoup

soup = BeautifulSoup(response.text, 'html.parser')

soup.find('h3').a['href'].split('/url?q=')[1]
# Out:
# 'https://mosaicscience.com/story/anosognosia-assisted-outpatient-treatment-lauras-law&sa=U&ved=0ahUKEwjk2uTvtd3dAhXVFsAKHZT7BkYQFggWMAA&usg=AOvVaw2qDV_vhpCDSOIqmWRh-QNf'

# %%
soup.find('h3', {'class': 'r'})
# Out:
# <h3 class="r"><a href="/url?q=https://mosaicscience.com/story/anosognosia-assisted-outpatient-treatment-lauras-law&amp;sa=U&amp;ved=0ahUKEwjk2uTvtd3dAhXVFsAKHZT7BkYQFggWMAA&amp;usg=AOvVaw2qDV_vhpCDSOIqmWRh-QNf">How can you <b>treat someone</b> who <b>doesn't accept they</b> are <b>ill</b>? | Mosaic</a></h3>
