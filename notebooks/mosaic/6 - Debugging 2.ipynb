# %%
try:
    import Image
except ImportError:
    from PIL import Image
import pytesseract

import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np

# %matplotlib inline

# %%
IMAGES_PATH = '/Users/sorrosn/Desktop/ocr_images/mosaic/'

def run_ocr(img_path):

    img=Image.open(img_path)
    img = img.rotate(-90)

    ocr_text = pytesseract.image_to_string(img)
    ocr_title = ocr_text.split('\n\n')[0]

    print(f"OCR text: {ocr_text}")
    print(f"OCR title: {ocr_title}")
    plt.imshow(np.asarray(img))

# %%
dataset = [
    ('IMG_3896.JPG', 'https://mosaicscience.com/story/parkinsons-disease-psychosis'),
    ('IMG_5346.JPG', 'https://mosaicscience.com/story/experience-expertise-care-health-research'),
    ('IMG_1473.JPG', 'https://mosaicscience.com/story/developmental-delay-disorders-milestones-childhood-genetic'),
    ('IMG_4463.JPG', 'https://mosaicscience.com/story/why-good-people-turn-bad-online-science-trolls-abuse'),
    ('IMG_4910.JPG', 'https://mosaicscience.com/story/sick-building-syndrome-buildings-or-people'),
    ('IMG_5888.JPG', 'https://mosaicscience.com/story/deep-brain-stimulation-depression-clinical-trial'),
    ('IMG_4199.JPG', 'https://mosaicscience.com/story/anosognosia-assisted-outpatient-treatment-lauras-law')
]

# %%
img_name = dataset[0][0]
img_path = f"{IMAGES_PATH}/{img_name}"
run_ocr(img_path)
# Out:
# OCR text: “Then Jay began seeing black cats eve/ywhere in the
# house. He believed there were groups of people on the
# property at night too, and that a creature called Big Boy
#
# was in their bed with them. Sometimes, he believed
#
# he’d whi/ed away whole afternoons talking to his
# brother in the living room of their cosy California
# home south of Los Angeles. ”
#
# Find the full story at mosaicscience.com
# OCR title: “Then Jay began seeing black cats eve/ywhere in the
# house. He believed there were groups of people on the
# property at night too, and that a creature called Big Boy

# %%
img_name = dataset[1][0]
img_path = f"{IMAGES_PATH}/{img_name}"
run_ocr(img_path)
# Out:
# OCR text: Most care leavers say they survived the system...
# I survived because of the system
#
# Many people Who have grown up in care in the UK Will say that they
# “survived the system”. Aine Kelly says she survived because of the
# system. Today, with support from Wellcome, she is studying for a PhD
# on the health experiences of Children in care.
#
# Historically, service users — the very people Who know most about the
# system from the inside — have been denied a voice in how to improve
#
# it. Things are changing, though, as service providers involve users
# more in their research and reform.
#
# Aine is a living example of this combination of expertise and
# experience. But as she has discovered, some people still struggle to
# acknowledge the beneﬁt it brings.
# OCR title: Most care leavers say they survived the system...
# I survived because of the system

# %%
img_name = dataset[2][0]
img_path = f"{IMAGES_PATH}/{img_name}"
run_ocr(img_path)
# Out:
# OCR text: Searching for a diagnosis: how
# scientists are untangling the
#
# mystery of developmental
# disorders
#
# What’s in a name? For the families of children suffering
# with undiagnosed, rare disorders, a name offers hope
# and reassurance.
#
# Evie Walker, 8 years old, finally received a diagnosis
# after years of uncertainty.
#
# We see how, from opposite sides of the world, genetic
# similarities have joined families together.
# OCR title: Searching for a diagnosis: how
# scientists are untangling the

# %%
img_name = dataset[3][0]
img_path = f"{IMAGES_PATH}/{img_name}"
run_ocr(img_path)
# Out:
# OCR text: Why good people turn had
# online
#
# Social media wasn't designed to be antisocial.
#
# However, as it has grown, it has evolved to divide us into
# bubbles of socially, economically and racially similar
# groups that do not reflect the society we live in.
#
# This week on Mosaic, meet the scientists finding out how
# can we defeat our inner trolls and build more cooperative
#
# digital societies.
# OCR title: Why good people turn had
# online

# %%
img_name = dataset[4][0]
img_path = f"{IMAGES_PATH}/{img_name}"
run_ocr(img_path)
# Out:
# OCR text: Sick building syndrome: is it
# the buildings or the people
# who need treatment?
#
# Some people in Finland are abandoning their workplaces
# and homes because they think that they are making
# them ill.
#
# Shayla Love tackles sick building syndrome, meeting the
# people that fear they will be labelled mentally ill, and the
# scientists searching for evidence that the condition is
# ‘real’.
# OCR title: Sick building syndrome: is it
# the buildings or the people
# who need treatment?

# %%
img.size
# Out:
# (4032, 3024)

# %%
img.resize((40,30))
# Out:
# <PIL.Image.Image image mode=RGB size=40x30 at 0x115E174E0>
